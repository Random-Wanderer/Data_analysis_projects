# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load csv
catalogue = pd.read_csv('cdli-catalogue.csv')
catalogue.head()
# Out:
# /Users/lorenzo/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,9,22,23,24,25,28,29,52,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   accession_no accounting_period acquisition_history alternative_years  \
# 0          NaN               NaN                 NaN               NaN
# 1          NaN               NaN                 NaN               NaN
# 2          NaN               NaN                 NaN               NaN
# 3          NaN               NaN                 NaN               NaN
# 4          NaN               NaN                 NaN               NaN
#
#          ark_number          atf_source atf_up  \
# 0  21198/zz001q0dtm  Englund, Robert K.    NaN
# 1  21198/zz001q0dv4  Englund, Robert K.    NaN
# 2  21198/zz001q0dwn  Englund, Robert K.    NaN
# 3  21198/zz001q0dx5  Englund, Robert K.    NaN
# ...

# %%
# Load Akkadian signs csv
ak_signs = pd.read_csv('old-akkadian-signs.csv')
ak_signs
# Out:
#             a
# 0           A
# 1          a2
# 2          A2
# 3          a3
# 4          a'
# ..        ...
# 588    8(asz)
# 589    9(asz)
# 590  1(asz@t)
# 591  2(asz@t)
# 592   3(ban2)
#
# [593 rows x 1 columns]

# %%
# Load Akkadian words csv
ak_words = pd.read_csv('old-akkadian-words.csv')
ak_words
# Out:
#                   a
# 0       a-1/2(disz)
# 1       a-2/3(disz)
# 2         a-1(disz)
# 3          a-2(asz)
# 4         a-2(disz)
# ...             ...
# 17986    8(disz)-mu
# 17987  8(disz)-sze3
# 17988  8(disz).sze3
# 17989       9(disz)
# 17990  9(disz)-sze3
#
# [17991 rows x 1 columns]

# %%
# Load ur3 sign
ur_sign = pd.read_csv('ur3-signs.csv', error_bad_lines= False)
ur_sign
# Out:
# /Users/lorenzo/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
# Load ur_words
ur_words = pd.read_csv('ur3-words.csv')
ur_words
# Out:
#                      a
# 0                    A
# 1                ...-a
# 2            ...-a-...
# 3                a-...
# 4              a-...-a
# ...                ...
# 62688    9(gesz2)-sze3
# 62689       9(gesz2@c)
# 62690         9(szar2)
# 62691       9(szargal)
# 62692  9(szargal){gal}
#
# [62693 rows x 1 columns]

# %%
# Catalogue info
catalogue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322717 entries, 0 to 322716
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accession_no              63516 non-null   object
#  1   accounting_period         3846 non-null    object
#  2   acquisition_history       21664 non-null   object
#  3   alternative_years         1819 non-null    object
#  4   ark_number                284304 non-null  object
#  5   atf_source                104976 non-null  object
#  6   atf_up                    4645 non-null    object
#  7   author                    308768 non-null  object
#  8   author_remarks            15374 non-null   object
#  9   cdli_collation            3391 non-null    object
#  10  cdli_comments             12603 non-null   object
#  11  citation                  12287 non-null   object
#  12  collection                313282 non-null  object
# ...

# %%
# Drop columns with large NA
short_catalogue = catalogue.drop(['accession_no', 'accounting_period', 'acquisition_history', 'alternative_years', 'atf_source', 'atf_up', 'author',
                                 'electronic_publication', 'date_entered', 'primary_publication', 'publication_date', 'publication_history', 'published_collation',
                                 'date_remarks', 'date_updated', 'photo_up', 'google_earth_provenience', 'google_earth_collection','citation', 'collection',
                                 'cdli_collation', 'cdli_comments', 'stratigraphic_level', 'dumb', 'dumb2', 'elevation', 'translation_source', 'date_of_origin', 'dates_referenced',
                                 'findspot_remarks', 'join_information', 'findspot_square', 'composite', ], axis= 1)
short_catalogue.head()
# Out:
#          ark_number                                     author_remarks  \
# 0  21198/zz001q0dtm  31x61x18; Lú A 14-16.30-32.48-50; M XVIII, auf...
# 1  21198/zz001q0dv4  30x48x13; Lú A 13-15.23-25.?; Fundstelle wie W...
# 2  21198/zz001q0dwn  42x53x19; Vocabulary 9; Qa XVI,2, unter der Ab...
# 3  21198/zz001q0dx5  26x23x23; Lú A 9-10.?.?; Fundstelle wie W 9123...
# 4  21198/zz001q0dzp  29x36x20; Lú A Vorläufer; Qa XVI,2, unter der ...
#
#   condition_description                          db_source  \
# 0                   NaN  20011204 protocuneiform_catalogue
# 1                   NaN  20011204 protocuneiform_catalogue
# 2                   NaN  20011204 protocuneiform_catalogue
# 3                   NaN  20011204 protocuneiform_catalogue
# 4                   NaN  20011204 protocuneiform_catalogue
#
#                     designation excavation_no external_id    genre height  \
# 0  CDLI Lexical 000002, ex. 065     W 06435,a         NaN  Lexical     31
# ...

# %%
# Location where found
provenience_counts = catalogue['provenience'].value_counts()
provenience_counts
# Out:
# Girsu (mod. Tello)                     33865
# Umma (mod. Tell Jokha)                 32697
# Nippur (mod. Nuffar)                   26557
# Nineveh (mod. Kuyunjik)                25338
# uncertain (mod. uncertain)             18821
#                                        ...
# uncertain (mod. northern Babylonia)        1
# uncertain (mod. Tell Atshana)              1
# Kazallu (mod. uncertain) ?                 1
# Ecbatana (mod. uncertain)                  1
# Alalakh (mod. Tell Atchana)                1
# Name: provenience, Length: 382, dtype: int64

# %%
# Remarks
catalogue['provenience_remarks'].value_counts()
# Out:
# Selim                                          436
# "Textes administratifs de la salle 5"          300
# antiquities market                             288
# "Textes administratifs de la salle 110"        279
# Ezida                                          232
#                                               ...
# Ibzaikh ?                                        1
# Maeda ASJ 17, 155                                1
# Tell Ingharra                                    1
# Girsu according to Veldhuis, Fs Sigrist 226      1
# Irisagrig (mod. uncertain) ?                     1
# Name: provenience_remarks, Length: 454, dtype: int64

# %%
# When found
catalogue['date_of_origin'].value_counts()
# Out:
# 00.00.00.00                6897
# --.--.00.00                3756
# Gudea.00.00.00             3050
# --.--.--.--                2049
# Assurnasirpal2.00.00.00    1332
#                            ...
# Amar-Suen.01.10.06            1
# Shulgi.48.07.08               1
# Shu-Suen.05.02.03             1
# Rimsin (Larsa).48.04.--       1
# --.--.10.07                   1
# Name: date_of_origin, Length: 25984, dtype: int64

# %%
# Time period
catalogue['period'].value_counts()
# Out:
# Ur III (ca. 2100-2000 BC)                                             102998
# Old Babylonian (ca. 1900-1600 BC)                                      52485
# Neo-Assyrian (ca. 911-612 BC)                                          33268
# Middle Hittite (ca. 1500-1100 BC)                                      14675
# Neo-Babylonian (ca. 626-539 BC)                                        13272
#                                                                        ...
# Middle Assyrian; note the string-hole                                      1
# copy (modern)                                                              1
# Old Akkadian (ca. 2340-2200 BC); Middle Elamite (ca. 1300-1000 BC)         1
# ED IIIa (ca. 2600-2500 BC), Old Babylonian (ca. 1900-1600 BC)              1
# Ebla (ca. 2350-2250 BC) ?                                                  1
# Name: period, Length: 68, dtype: int64

# %%
# Context
catalogue['stratigraphic_level'].value_counts()
# Out:
# II                                                                  29
# 18 1-2                                                              22
# 3                                                                   19
# 2                                                                    8
# 17B2                                                                 6
# 18 3                                                                 5
# 17A                                                                  4
# 16C                                                                  4
# 17A-16 (contact)                                                     3
# 15A                                                                  3
# XIIA                                                                 3
# Nabu temple                                                          2
# 16                                                                   2
# ...

# %%
# Found by who
found_by = catalogue['atf_source'].value_counts()
found_by, found_by.count()
# Out:
# (cdli staff                                                     34454
#  no atf                                                          8806
#  Englund, Robert K.                                              6570
#  Sigrist, Marcel                                                 5970
#  Foxvog, Daniel A.                                               5115
#                                                                 ...
#  al-Rawi, Farouk N. H.; Gorello, Francesca; Notizia, Palmiro        1
#  Notizia, Palmiro; Verderame, Lorenzo                               1
#  Geller, Markham J.                                                 1
#  Washburn, Jody E.                                                  1
#  Lauinger, Jacob (Oracc)                                            1
#  Name: atf_source, Length: 213, dtype: int64,
#  213)

# %%
# Most common material
material = catalogue['material'].value_counts()
material.head(10)
# Out:
# clay                   294130
# stone                    7250
# stone ?                  5338
# composite                3000
# stone: limestone          968
# metal: bronze             246
# stone: alabaster          209
# stone: lapis lazuli       202
# stone: calcite            198
# bone: ivory ?             186
# Name: material, dtype: int64

# %%
# Just clay
clay = catalogue[catalogue['material'] == 'clay']
clay
# Out:
#        accession_no accounting_period acquisition_history alternative_years  \
# 0               NaN               NaN                 NaN               NaN
# 1               NaN               NaN                 NaN               NaN
# 2               NaN               NaN                 NaN               NaN
# 3               NaN               NaN                 NaN               NaN
# 4               NaN               NaN                 NaN               NaN
# ...             ...               ...                 ...               ...
# 322712          NaN               NaN                 NaN               NaN
# 322713          NaN               NaN                 NaN               NaN
# 322714          NaN               NaN                 NaN               NaN
# 322715          NaN               NaN                 NaN               NaN
# 322716          NaN               NaN                 NaN               NaN
#
#               ark_number          atf_source atf_up  \
# ...

# %%
# Clay by period
clay['period'].value_counts()
# Out:
# Ur III (ca. 2100-2000 BC)                                         96617
# Old Babylonian (ca. 1900-1600 BC)                                 49628
# Neo-Assyrian (ca. 911-612 BC)                                     30055
# Middle Hittite (ca. 1500-1100 BC)                                 14675
# Neo-Babylonian (ca. 626-539 BC)                                   11667
# Middle Babylonian (ca. 1400-1100 BC)                              11076
# Old Akkadian (ca. 2340-2200 BC)                                    8457
# Ebla (ca. 2350-2250 BC)                                            7101
# Old Assyrian (ca. 1950-1850 BC)                                    6040
# Early Old Babylonian (ca. 2000-1900 BC)                            6023
# Uruk III (ca. 3200-3000 BC)                                        4396
# Achaemenid (547-331 BC)                                            4383
# Lagash II (ca. 2200-2100 BC)                                       3872
# ...

# %%
# Stone
stone = catalogue[catalogue['material'] == 'stone']
stone
# Out:
#               accession_no accounting_period acquisition_history  \
# 5635                   NaN               NaN                 NaN
# 5650    not in metonline ?               NaN                 NaN
# 5651                   NaN               NaN       Brummer, 1941
# 5652                   NaN               NaN                 NaN
# 5654                   NaN               NaN                 NaN
# ...                    ...               ...                 ...
# 321536                 NaN               NaN                 NaN
# 321537                 NaN               NaN                 NaN
# 321717                 NaN               NaN                 NaN
# 322585                 NaN               NaN                 NaN
# 322705    1880-12-16, 0047               NaN                 NaN
#
#        alternative_years        ark_number          atf_source atf_up  \
# 5635                 NaN  21198/zz001r2gpt  Englund, Robert K.    NaN
# ...

# %%
# Stone by period
stone['period'].value_counts()
# Out:
# Old Babylonian (ca. 1900-1600 BC)          1608
# Neo-Assyrian (ca. 911-612 BC)              1376
# Old Akkadian (ca. 2340-2200 BC)             618
# Ur III (ca. 2100-2000 BC)                   460
# Uruk III (ca. 3200-3000 BC)                 400
# ED I-II (ca. 2900-2700 BC)                  350
# Neo-Babylonian (ca. 626-539 BC)             294
# ED IIIb (ca. 2500-2340 BC)                  269
# Middle Assyrian (ca. 1400-1000 BC)          251
# ED IIIa (ca. 2600-2500 BC)                  205
# Lagash II (ca. 2200-2100 BC)                135
# Middle Babylonian (ca. 1400-1100 BC)        126
# Old Assyrian (ca. 1950-1850 BC)             126
# Early Old Babylonian (ca. 2000-1900 BC)      91
# Achaemenid (547-331 BC)                      82
# uncertain                                    14
# Uruk IV (ca. 3350-3200 BC)                   13
# Parthian (247 BC - 224 AD)                    8
# Old Babylonian (ca. 1900-1600 BC) ?           7
# Neo-Elamite (ca. 770-539 BC)                  7
# ...

# %%
# Metal
metal = catalogue[catalogue['material'] == 'metal']
metal
# Out:
#        accession_no accounting_period      acquisition_history  \
# 67639           NaN               NaN                      NaN
# 71221           NaN               NaN                      NaN
# 73873           NaN               NaN                      NaN
# 75511           NaN               NaN                      NaN
# 101871          NaN               NaN                      NaN
# 223391          NaN               NaN                      NaN
# 223423          NaN               NaN                      NaN
# 223436          NaN               NaN                      NaN
# 258255          NaN               NaN  was: www christie's 008
# 298565          NaN               NaN                      NaN
#
#        alternative_years        ark_number          atf_source atf_up  \
# 67639                NaN  21198/zz001thj1m   Foxvog, Daniel A.    NaN
# 71221                NaN  21198/zz001r4z5q          cdli staff    NaN
# ...

# %%
# Metal by period
metal['period'].value_counts()
# Out:
# Old Akkadian (ca. 2340-2200 BC)            1
# ED IIIb (ca. 2500-2340 BC)                 1
# Early Old Babylonian (ca. 2000-1900 BC)    1
# Ur III (ca. 2100-2000 BC)                  1
# Ur III (ca. 2100-2000 BC) ?                1
# Linear Elamite (ca. 2200 BC)               1
# Old Akkadian (ca. 2340-2200 BC) ?          1
# Middle Assyrian (ca. 1400-1000 BC)         1
# Name: period, dtype: int64
